# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
plt.rcParams["figure.figsize"] = 10, 8
plt.rcParams["font.size"     ] = 14

# %%
import os
import sys
import glob
import time
import warnings
import datetime 
print("Last updated on ", time.asctime())
# Out:
# Last updated on  Tue Jan 21 10:01:39 2020

# %%
import numpy as np
import pandas as pd
import matplotlib

# %%
from mpl_toolkits.mplot3d import Axes3D
from enum import Enum
from scipy.linalg import norm

# %%
from dataclasses import dataclass
import abc
from typing import Sequence

from pynext.system_of_units import *
from pynext.graphics import draw_cylinder
from pynext.graphics import draw_sphere
from pynext.graphics import draw_vuv
from pynext.graphics import draw_spherical_sample
from pynext.pynext_types import Cylinder, Sphere

# %%
from pynext.pynext_base import sample_spherical
from pynext.pynext_base import vuv_transport
from pynext.pynext_base import  xyz_from_vuv
from pynext.pynext_base import  vuv_fractions

# %% [markdown]
# # Defines and draws a cylinder

# %%
r    = 0.5
zmin = -0.6
zmax = 0.6
c =Cylinder(r, zmin, zmax)
c
# Out:
# Cylinder(r=0.5, zmin=-0.6, zmax=0.6, p0=array([ 0. ,  0. , -0.6]), p1=array([0. , 0. , 0.6]))

# %%
draw_cylinder(c, alpha=0.5)

# %% [markdown]
# # Defines and draws a sphere

# %%
sp = Sphere(1)

# %%
draw_sphere(sp)

# %% [markdown]
# ## Draws randowm points in the surface of a sphere

# %%
draw_spherical_sample(sp, npoints=1000)

# %% [markdown]
# ## Generates rays going from the cylinder center to the surface. Draw the points and the rays

# %%
vuv = vuv_transport(c, p=np.array([0,0,0]), nphotons=100)

# %%
draw_vuv(vuv, c, tscale=1)

# %% [markdown]
# ## Draw the points only

# %%
vuv = vuv_transport(c, p=np.array([0,0,0]), nphotons=100000)

# %%
draw_vuv(vuv, c, drawRays=False)

# %% [markdown]
# ## Which fraction of the VUV photons are in the end-cups?

# %%
fzmin, fzmax, fbarrel = vuv_fractions(vuv, zmin, zmax)
print(fzmin, fzmax, fbarrel)
# Out:
# 0.11636 0.11682 0.76682
